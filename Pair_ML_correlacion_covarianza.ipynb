# %%
import pandas as pd 
import sidetable as stb
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (10,8)
pd.options.display.max_columns = None

# %% [markdown]
# En este ejercicio de pair programming seguiréis usando el dataset que seleccionasteis ayer.
#
# 1. Pregunta teórica: ¿Qué diferencia existe entre la covarianza y la correlación?
#
#     La covarianza indica la dirección de la relación entre dos variables y la correlación nos indica también la intensidad de esa relación

# %% [markdown]
# 2. Calculad la covarianza y la correlación de nuestro dataset. No nos vale solo con que la calculéis, debéis hacer una interpretación de los resultados obtenidos. Calculad solo la correlación de Pearson.

# %%
df = pd.read_csv('data/supermarket_1.csv', index_col = 0)
df.sample(10)
# Out:
#       invoice_id branch       city customer_type  gender  \
# 771  759-98-4285      C  Naypyitaw        Member  Female
# 246  866-05-7563      B   Mandalay        Member  Female
# 993  690-01-6631      B   Mandalay        Normal    Male
# 280  136-08-6195      A     Yangon        Normal  Female
# 618  828-46-6863      A     Yangon        Member    Male
# 545  701-23-5550      B   Mandalay        Member    Male
# 602  373-09-4567      C  Naypyitaw        Normal    Male
# 342  873-95-4984      B   Mandalay        Member  Female
# 518  220-28-1851      A     Yangon        Normal    Male
# 123  336-78-2147      C  Naypyitaw        Member    Male
#
#                product_line  unit_price  quantity   tax_5%     total  \
# 771       Health and beauty       85.87         7  30.0545  631.1445
# 246  Electronic accessories       81.40         3  12.2100  256.4100
# 993     Fashion accessories       17.49        10   8.7450  183.6450
# 280      Home and lifestyle       69.96         8  27.9840  587.6640
# 618      Food and beverages       98.53         6  29.5590  620.7390
# 545      Home and lifestyle       38.81         4   7.7620  163.0020
# 602      Food and beverages       77.56        10  38.7800  814.3800
# 342       Health and beauty       76.90         7  26.9150  565.2150
# 518      Home and lifestyle       34.73         2   3.4730   72.9330
# 123      Home and lifestyle       63.91         8  25.5640  536.8440
#
#           date   time      payment    cogs  gross_income  rating
# 771  2/27/2019  19:01  Credit card  601.09       30.0545     8.0
# 246   2/9/2019  19:43         Cash  244.20       12.2100     4.8
# 993  2/22/2019  18:35      Ewallet  174.90        8.7450     6.6
# 280  2/15/2019  17:01  Credit card  559.68       27.9840     6.4
# 618  1/23/2019  11:22  Credit card  591.18       29.5590     4.0
# 545  3/19/2019  13:40      Ewallet  155.24        7.7620     4.9
# 602  3/14/2019  20:35      Ewallet  775.60       38.7800     6.9
# 342  2/15/2019  20:21         Cash  538.30       26.9150     7.7
# 518   3/1/2019  18:14      Ewallet   69.46        3.4730     9.7
# 123  3/13/2019  19:52  Credit card  511.28       25.5640     4.6

# %%
df_num = df.select_dtypes(include= ["float64", "int64"])
df_num.sample(2)
# Out:
#      unit_price  quantity   tax_5%     total    cogs  gross_income  rating
# 704       88.39         9  39.7755  835.2855  795.51       39.7755     6.3
# 186       94.49         8  37.7960  793.7160  755.92       37.7960     7.5

# %%
df_num.cov()
# Out:
#                unit_price    quantity       tax_5%         total  \
# unit_price     701.965331    0.834778   196.668340   4130.035142
# quantity         0.834778    8.546446    24.149570    507.140978
# tax_5%         196.668340   24.149570   137.096594   2879.028477
# total         4130.035142  507.140978  2879.028477  60459.598018
# cogs          3933.366802  482.991408  2741.931883  57580.569541
# gross_income   196.668340   24.149570   137.096594   2879.028477
# rating          -0.399668   -0.079456    -0.733300    -15.399306
#
#                       cogs  gross_income     rating
# unit_price     3933.366802    196.668340  -0.399668
# quantity        482.991408     24.149570  -0.079456
# tax_5%         2741.931883    137.096594  -0.733300
# total         57580.569541   2879.028477 -15.399306
# cogs          54838.637658   2741.931883 -14.666006
# gross_income   2741.931883    137.096594  -0.733300
# rating          -14.666006     -0.733300   2.953518

# %%
df_num.corr()
# Out:
#               unit_price  quantity    tax_5%     total      cogs  \
# unit_price      1.000000  0.010778  0.633962  0.633962  0.633962
# quantity        0.010778  1.000000  0.705510  0.705510  0.705510
# tax_5%          0.633962  0.705510  1.000000  1.000000  1.000000
# total           0.633962  0.705510  1.000000  1.000000  1.000000
# cogs            0.633962  0.705510  1.000000  1.000000  1.000000
# gross_income    0.633962  0.705510  1.000000  1.000000  1.000000
# rating         -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#               gross_income    rating
# unit_price        0.633962 -0.008778
# quantity          0.705510 -0.015815
# tax_5%            1.000000 -0.036442
# total             1.000000 -0.036442
# cogs              1.000000 -0.036442
# gross_income      1.000000 -0.036442
# rating           -0.036442  1.000000

# %% [markdown]
# - Interpretación de los resultados obtenidos

# %%
#Calculamos la correlación de Pearson

# %% [markdown]
# 3. Con los resultados de la correlación del ejercicio anterior, cread un heatmap.

# %%
sns.heatmap(df_num.corr(),
            vmax = 1,
            vmin = -1,
            cmap = "YlGnBu",
           annot = True);

# %% [markdown]
# 4. Guardad la gráfica del heatmap.
