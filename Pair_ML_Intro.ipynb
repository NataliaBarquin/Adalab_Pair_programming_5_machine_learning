# %%
import pandas as pd 
import sidetable as stb

pd.options.display.max_columns = None

# %%
df = pd.read_csv("data/soci_econ_country_profiles.csv", index_col = 0)
df.sample(5)
# Out:
#                country         Region  Surface area (km2)  \
# 12            Colombia   SouthAmerica             1141748
# 20              France  WesternEurope              551500
# 37         New Zealand        Oceania              268107
# 46  Russian Federation  EasternEurope            17098246
# 50            Slovakia  EasternEurope               49035
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 12                           49066                                44.2
# 20                           64980                               118.7
# 37                            4706                                17.9
# 46                          143990                                 8.8
# 50                            5448                               113.3
#
#     Sex ratio (m per 100 f, 2017)  \
# 12                           96.8
# 20                           96.7
# 37                           96.7
# 46                           86.8
# ...

# %%
df.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'Population density (per km2, 2017)',
#        'Sex ratio (m per 100 f, 2017)',
#        'GDP: Gross domestic product (million current US$)',
#        'GDP growth rate (annual %, const. 2005 prices)',
#        'GDP per capita (current US$)', 'Economy: Agriculture (% of GVA)',
#        'Economy: Industry (% of GVA)',
#        'Economy: Services and other activity (% of GVA)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Industry (% of employed)',
#        'Employment: Services (% of employed)',
#        'Unemployment (% of labour force)',
#        'Labour force participation (female/male pop. %)',
#        'Agricultural production index (2004-2006=100)',
#        'Food production index (2004-2006=100)',
#        'International trade: Exports (million US$)',
#        'International trade: Imports (million US$)',
# ...

# %%
df.shape
# Out:
# (66, 95)

# %%
df.describe().T
# Out:
#                                                     count          mean  \
# Surface area (km2)                                   66.0  1.383839e+06
# Population in thousands (2017)                       66.0  8.655136e+04
# Population density (per km2, 2017)                   66.0  3.677606e+02
# Sex ratio (m per 100 f, 2017)                        66.0  1.030939e+02
# GDP: Gross domestic product (million current US$)    66.0  1.054143e+06
# ...                                                   ...           ...
# Population, female                                   66.0  4.264709e+07
# Population, male                                     66.0  4.363543e+07
# Tax revenue (% of GDP)                               58.0  1.751490e+01
# Taxes on income, profits and capital gains (% o...   57.0  2.639972e+01
# Urban population (% of total population)_y           66.0  7.231921e+01
#
#                                                              std  \
# ...

# %%
df.describe(include= "O").T
# Out:
#                                                    count unique  \
# country                                               66     66
# Region                                                66     14
# Economy: Agriculture (% of GVA)                       66     44
# Labour force participation (female/male pop. %)       66     66
# Population growth rate (average annual %)             66     34
# Urban population growth rate (average annual %)       66     32
# Population age distribution (0-14 / 60+ years, %)     66     66
# International migrant stock (000/% of total pop.)     66     66
# Refugees and others of concern to UNHCR (in tho...    66     66
# Health: Physicians (per 1000 pop.)                    66     36
# Education: Government expenditure (% of GDP)          66     35
# Education: Primary gross enrol. ratio (f/m per ...    66     63
# Education: Secondary gross enrol. ratio (f/m pe...    66     63
# Education: Tertiary gross enrol. ratio (f/m per...    66     63
# ...

# %%
# chequeamos tipo

df.dtypes
# Out:
# country                                                       object
# Region                                                        object
# Surface area (km2)                                             int64
# Population in thousands (2017)                                 int64
# Population density (per km2, 2017)                           float64
#                                                               ...
# Population, female                                           float64
# Population, male                                             float64
# Tax revenue (% of GDP)                                       float64
# Taxes on income, profits and capital gains (% of revenue)    float64
# Urban population (% of total population)_y                   float64
# Length: 95, dtype: object

# %%
# extraemos información sobre nulos

df.stb.missing()
# Out:
#                                                     missing  total    percent
# Taxes on income, profits and capital gains (% o...        9     66  13.636364
# Air transport, freight (million ton-km)                   8     66  12.121212
# Tax revenue (% of GDP)                                    8     66  12.121212
# Air transport, passengers carried                         5     66   7.575758
# Commercial service exports (current US$)                  3     66   4.545455
# ...                                                     ...    ...        ...
# Refugees and others of concern to UNHCR (in tho...        0     66   0.000000
# International migrant stock (000/% of total pop.)         0     66   0.000000
# Population age distribution (0-14 / 60+ years, %)         0     66   0.000000
# Fertility rate, total (live births per woman)             0     66   0.000000
# Urban population (% of total population)_y                0     66   0.000000
#
# [95 rows x 3 columns]

# %%
# comprobar duplicados

df.duplicated().sum()
# Out:
# 0

# %%
# calcular outliers:
